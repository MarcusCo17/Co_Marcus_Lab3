# %%
191249
Co
2 BS ITE

# %%
social_graph = {
    "@bongolpoc":{"first_name":"Joselito",
                  "last_name":"Olpoc",
                  "following":[
                  ]
    },
    "@joaquin":  {"first_name":"Joaquin",
                  "last_name":"Gonzales",
                  "following":[
                      "@chums","@jobenilagan"
                  ]
    },
    "@chums" : {"first_name":"Matthew",
                "last_name":"Uy",
                "following":[
                    "@bongolpoc","@miketan","@rudyang","@joeilagan"
                ]
    },
    "@jobenilagan":{"first_name":"Joben",
                   "last_name":"Ilagan",
                   "following":[
                    "@eeebeee","@joeilagan","@chums","@joaquin"
                   ]
    },
    "@joeilagan":{"first_name":"Joe",
                  "last_name":"Ilagan",
                  "following":[
                    "@eeebeee","@jobenilagan","@chums"
                  ]
    },
    "@eeebeee":  {"first_name":"Elizabeth",
                  "last_name":"Ilagan",
                  "following":[
                    "@jobenilagan","@joeilagan"
                  ]
    },
}

def relationship_status(from_member, to_member):
    if to_member in social_graph[from_member]["following"] and from_member in social_graph[to_member]["following"]:
        print("friends")
    elif from_member in social_graph[to_member]["following"]:
        print("followed by")
    elif to_member in social_graph[from_member]["following"]:
        print("follower")   

from_member = input("First Person: ")
to_member = input("Second Person: ")


relationship_status(from_member, to_member)
# Out:
# First Person: @chums
# Second Person: @jobenilagan
# followed by

# %%
# Out:
#  [ ['X','','X'], ['','X',''], ['','','X'], ]
# Choose a board to check:  [ ['X','','X'], ['','X',''], ['','','X'], ]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-61-2157e96299c3> in <module>
#      26 boardd = input("Choose a board to check: ")
#      27
# ---> 28 tictactoegame(board)
#      29
#
# <ipython-input-61-2157e96299c3> in tictactoegame(boardd)
#       3     y=list(x for x in boardd)
#       4     #checking horizontal
# ----> 5     if y[0][0]==y[0][1]==y[0][2]:
#       6         print("Winner1")
#       7     elif y[1][0]==y[1][1]==y[1][2]:
#
# IndexError: string index out of range

# %% [raw]
# board1 = [
# ['X','X','O'],
# ['O','X','O'],
# ['O','','X'],
# ]
#
# board2 = [
# ['X','X','O'],
# ['O','X','O'],
# ['','O','X'],
# ]
#
# board3 = [
# ['O','X','O'],
# ['','O','X'],
# ['X','X','O'],
# ]
#
# board4 = [
# ['X','X','X'],
# ['O','X','O'],
# ['O','','O'],
# ]
#
# board5 = [
# ['X','X','O'],
# ['O','X','O'],
# ['X','','O'],
# ]
#
# board6 = [
# ['X','X','O'],
# ['O','X','O'],
# ['X','',''],
# ]
#
# board7 = [
# ['X','','X'],
# ['','X',''],
# ['','','X'],
# ]
#
# print(board)
# def tictactoegame(boardd):
#     y=list(x for x in boardd)
#
#     #checking horizontal
#     if y[0][0]==y[0][1]==y[0][2]:
#         print("Winner1")
#     elif y[1][0]==y[1][1]==y[1][2]:
#         print("Winner2")
#     elif y[2][0]==y[2][1]==y[2][2]:
#         print("Winner3")
#
#     #checking vertical
#     elif y[0][0]==y[1][0]==y[2][0]:
#         print("Winner4")
#     elif y[0][1]==y[1][1]==y[2][1]:
#         print("Winner5")
#     elif y[0][2]==y[1][2]==y[2][2]:
#         print("Winner6")
#
#     #Checking Diagonals
#     elif y[0][0]==y[1][1]==y[2][2]:
#         print("Winner7")
#     elif y[2][0]==y[1][1]==y[0][2]:
#         print("Winner8")
#
# boardd = input("Choose a board to check: ")
#
# tictactoegame(boardd)

# %%
board1 = [
['X','X','O'],
['O','X','O'],
['O','','X'],
]

board2 = [
['X','X','O'],
['O','X','O'],
['','O','X'],
]

board3 = [
['O','X','O'],
['','O','X'],
['X','X','O'],
]

board4 = [
['X','X','X'],
['O','X','O'],
['O','','O'],
]

board5 = [
['X','X','O'],
['O','X','O'],
['X','','O'],
]

board6 = [
['X','X','O'],
['O','X','O'],
['X','',''],
]

board7 = [
['X','','X'],
['','X',''],
['','','X'],
]

#note i inputted "Winner #" to differentiate different winner by type (row, column, diagonal)

#note, hi sir could you please help me debug my code. I included the code i used
#to try making it a function but idk why it doesnt wanna work, thank you

y=list(x for x in board7) 
#checking horizontal
if y[0][0]==y[0][1]==y[0][2]:
    print("Winner1: ", y[0][0])
elif y[1][0]==y[1][1]==y[1][2]:
    print("Winner2: ", y[1][0])
elif y[2][0]==y[2][1]==y[2][2]:
    print("Winner3: ", y[2][0])

    #checking vertical
elif y[0][0]==y[1][0]==y[2][0]:
    print("Winner4: ", y[0][0])
elif y[0][1]==y[1][1]==y[2][1]:
    print("Winner5: ", y[0][1])
elif y[0][2]==y[1][2]==y[2][2]:
    print("Winner6: ", y[0][2])

    #Checking Diagonals
elif y[0][0]==y[1][1]==y[2][2]:
    print("Winner7: ", y[0][0])
elif y[2][0]==y[1][1]==y[0][2]:
    print("Winner8: ", y[2][0])
# Out:
# Winner7:  X

# %%
locations = {
    "admu":{
        "name":"Ateneo de Manila University",
        "latitude":14.6394557,
        "longitude":121.0758975        
    },
    "upd":{
        "name":"University of the Philippines-Diliman Campus",
        "latitude":14.6538519,
        "longitude":121.0663348
    },
    "dlsu":{
        "name":"De La Salle University-Taft",
        "latitude":14.5647346,
        "longitude":120.9909876

    }, # <-- Note that Python does not complain about this extra comma. This is perfectly okay.
       #     The creators of Python saw that dictionaries tend to be changed a lot, so allowing this is a
       #     convenience for developers who need to add elements when needed.
}

legs = {
     ("upd","admu"):{
         "travel_time_mins":10
     },
     ("admu","dlsu"):{
         "travel_time_mins":35
     },
     ("dlsu","upd"):{
         "travel_time_mins":55
     }
}



def etaa(source,destination):
    if source == "upd" and destination == "admu":
        traveltime = "10"
    elif source == "upd" and destination == "dlsu":
        traveltime = "45"
    elif source == "dlsu" and destination == "upd":
        traveltime = "55"
    elif source == "dlsu" and destination == "admu":
        traveltime = "65"
    elif source == "admu" and destination == "dlsu":
        traveltime = "35"
    elif source == "admu" and destination == "upd":
        traveltime = "90"
    print("ETA: ", traveltime)




source = input("Enter Source: ")
destination = input("Enter Destination: ")

etaa(source, destination)
# Out:
# Enter Source: admu
# Enter Destination: upd
# ETA:  90

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-28950a561f41> in <module>
# ----> 1 etaa()
#
# TypeError: etaa() missing 2 required positional arguments: 'source' and 'destination'
